# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import load_model
from predict import predict_img, read_image_from_url

# %% [markdown]
# ## Funciones de perdida y precisión

# %%
history = np.load('training_history.npy', allow_pickle=True).item()

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(history['loss'], label='Training Loss')
plt.plot(history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot training accuracy
plt.subplot(1, 2, 2)
plt.plot(history['accuracy'], label='Training Accuracy')
plt.plot(history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Las evoluciones de las funciones de perdida y accuracy siguen el movimiento esperado con una tendencia a la estabilidad.

# %% [markdown]
# ## Precision final

# %%
loaded_data = np.load('data/data.npz')
testX = loaded_data['testX']
testY = loaded_data['testY']

model = load_model("trained_models/lenet_best.h5")
_, acc = model.evaluate(testX, testY)
print(acc * 100.0)
# Out:
# WARNING:tensorflow:From c:\Users\angel\OneDrive\Documentos\RNN\Tarea 2 Soluciones\venv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\angel\OneDrive\Documentos\RNN\Tarea 2 Soluciones\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 313/313 [==============================] - 2s 4ms/step - loss: 0.4493 - accuracy: 0.8709
# 87.08999752998352

# %% [markdown]
# La precisión del modelo es de 87%, 17% mas de lo requierido. El modelo es aprobado.

# %% [markdown]
# ## Funcionamiento del modelo

# %%
ma_letter = read_image_from_url("https://en.pimg.jp/087/711/030/1/87711030.jpg")
ma_letter
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=389x450>

# %%
predict_img("https://en.pimg.jp/087/711/030/1/87711030.jpg")
# Out:
# 'ma'

# %%
ya_letter = read_image_from_url("https://en.pimg.jp/032/860/257/1/32860257.jpg")
ya_letter
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=450x468>

# %%
predict_img("https://en.pimg.jp/032/860/257/1/32860257.jpg")
# Out:
# 'ya'

# %% [markdown]
# El modelo funciona bastante bien para imagenes mucho mas grandes que con las que se entrenó.
